# %% [markdown]
# Walking habits Project
# By: Alan Poblette
# CPSC 222, Fall 2020
# # Introduction
# The domain of the walking habits project is fitness and it focuses on step count data sourced from Apple Health. The dataset is a collection of step entries with a value, date-time stamp, and multiple identifying information about the collection source (iphone, ios version, etc).
#
# For the project, we were looking for trends that would allow us to check how often and under what conditions step count increased. As part of the Exploratory Data Analysis we came up with a few hypotheses we wanted to test:
# 1. Step count will decrease after school starts on 09-01-2020
# 1. Step count will be lower on weekends vs weekdays.
# 1. Step count will be less on a holiday than a non-holiday.
#
# The result of our data analysis resulted in the following answers to the previous hypotheses:
# 1. Step count did NOT decrease after school started. It was equal or increased.
# 1. Step count was NOT lower on weekends vs weekdays. It was equal or greater.
# 1. Step count on a holiday was GREATER than a non-holiday.
#
# In terms of our classification, our best classifier was a linear regression model, but even that was at best inadequate. The decision tree model and kNN model with k=5 both had a 0% accuracy score. We had expected difficulty in classifying our data since it turned out to be very random on the day to day, and because of the lack of class features to classify by. However, 0% accuracy on two of the models was still alarming. The linear regression model had a mean squared error of $1616.521$, and an $R^2$ of $-0.2169$.

# %% [markdown]
# # Data Visualizations
# Here is my step counts visualized before doing any analysis on them.

# %%
import functions as func
import pandas as pd
import numpy as np
import scipy.stats as stats
import calendar
import datetime

steps_data_df = func.clean_xml('export.xml', save=True)

# %%
# add columns to distinguish datetimes by week day and month
steps_data_df['day of week (numeric)'] = pd.DatetimeIndex(steps_data_df['creationDate']).weekday
steps_data_df['day of week (string)'] = pd.DatetimeIndex(steps_data_df['creationDate']).strftime('%A')
steps_data_df['month'] = pd.DatetimeIndex(steps_data_df['creationDate']).month

func.plot_by_weekday(steps_data_df.groupby('day of week (numeric)'))

func.plot_by_day(steps_data_df.groupby(pd.Grouper(key='creationDate', freq='D')))

func.plot_by_week(steps_data_df.groupby(pd.Grouper(key='creationDate', freq='W')))

func.plot_by_month(steps_data_df.groupby(['month']))

# %%
daily_data_group = steps_data_df.groupby(pd.Grouper(key='creationDate', freq='D'))
daily_steps = pd.DataFrame(dtype=object, columns=['date', 'value'])

# the data has multiple entries per day of steps taken at different times so,
# group data to be by day
index = 0
for key, value in daily_data_group:
    daily_steps.loc[index, 'date'] = str(key)[0:10]
    daily_steps.loc[index, 'value'] = sum(value['value'])
    index += 1

print('Mean steps from 7/1/20 to 8/31/20', daily_steps[daily_steps.date < '2020-09-01']['value'].mean())
print('Mean steps from 9/1/20 to 10/19/20', daily_steps[daily_steps.date >= '2020-09-01']['value'].mean())
print()
print('std. deviation of total daily step counts:', np.std(daily_steps.value))
print('Min daily steps:', daily_steps['value'].min())
print('Max daily steps:', daily_steps['value'].max())
print('Median daily steps:', np.median(daily_steps['value']))
print('DF: ', len(steps_data_df))
# Out:
# Mean steps from 7/1/20 to 8/31/20 3214.9193548387098
# Mean steps from 9/1/20 to 10/19/20 5592.836734693878
#
# std. deviation of total daily step counts: 3143.43828776257
# Min daily steps: 649
# Max daily steps: 21875
# Median daily steps: 3536.0
# DF:  4028

# %%
# get request for holiday data
# get holidays from api
holiday_response = func.get_holidays()

# %%
# append useful information for classification later:

# set weekdays and month info and school start
func.append_classification_info(daily_steps)

# mark holidays
daily_steps['holiday'] = [0] * len(daily_steps['date'])
func.mark_holidays(daily_steps, holiday_response)

daily_steps.to_csv('check.csv')

# %% [markdown]
# # Quantified Self Project Hypothesis Testing
#
# ## Steps before school starts vs after school start
# For my project data I have hypothesized that on average the number of steps I take on a certain day will be less after school starts on septermber 1, 2020. I will test this hypothesis using a two sample, one tailed t-test. I will split my original data into two groups, one starting after school starts and one from before.
#
# ### Step 1:
# $H_0$: The average number of steps taken on a day before school starts $>$ the average number of steps taken on a day after school starts.
#
# $H_1$: The average number of steps taken on a day before school starts $\leq$ the average number of steps taken on a day after school starts.
# ### Step 2:
# For this test I will be using a level of significance of $0.005$.
# ### Step 3:
# for our two-sample independent test of means we will have:
#
# test-statistic = $t = \frac{\bar X_1 - \bar X_2}{\sqrt{S_p ^2 (\frac{1}{n_1} + \frac{1}{n_2})}}$.
# ### Step 4:
# df = 4028
# t-critical $= 2.576$
#
# **Decision Rule:**
#
# If t-computed $> 2.576$, then reject $H_0$.
#
# If t-computed $\leq 2.576$, then DO NOT reject $H_0$.
# ### Step 5

# %%
t_computed, p_value = stats.ttest_ind(daily_steps[daily_steps.school == 0]['value'], daily_steps[daily_steps.school == 1]['value'])
print(abs(t_computed), p_value / 2)
# Out:
# 4.23159941203336 2.4270875078724936e-05

# %% [markdown]
# Since t-computed $(4.23) > 2.567$ then we reject $H_0$ and fail to reject $H_1$: number of daily steps before school starts $\leq$ number of daily steps after school stars.
#
# This conclusion backs up our visualizations as we can see that the step count increases in the later half of our data backing up our hypothesis testing.

# %% [markdown]
# ## Weekday steps vs weekend steps
# For my project data I will hypothesize that on average the number of steps I take on a week end will be less than on a weekday. I will test this hypothesis using a two sample, one tailed t-test. I will split my original data into two groups, one for weekdays and one for weekends.
#
# ### Step 1:
# $H_0$: The average number of steps taken on a weekend $>$ the average number of steps taken on a weekday.
#
# $H_1$: The average number of steps taken on a weekend $\leq$ the average number of steps taken on a weekday
# ### Step 2:
# For this test I will be using a level of significance of $0.005$.
# ### Step 3:
# for our two-sample independent test of means we will have:
#
# test-statistic = $t = \frac{\bar X_1 - \bar X_2}{\sqrt{S_p ^2 (\frac{1}{n_1} + \frac{1}{n_2})}}$.
# ### Step 4:
# df = 4028
# t-critical $= 2.576$
#
# **Decision Rule:**
#
# If t-computed $> 2.576$, then reject $H_0$.
#
# If t-computed $\leq 2.576$, then DO NOT reject $H_0$.
# ### Step 5

# %%
t_computed, p_value = stats.ttest_ind(daily_steps['day of week'].between(0,4, inclusive=True), daily_steps['day of week'].between(5,6, inclusive=True))
print(abs(t_computed), p_value / 2)
# Out:
# 6.9325126045798315 2.2641919532114882e-11

# %% [markdown]
# Since t-computed $(6.93) > 2.567$ then we reject $H_0$ and fail to reject $H_1$: the average number of steps taken on a weekend $\leq$ the average number of steps taken on a weekday.
#
# ## Steps on Holidays
# For my project data I will hypothesize that on average the number of steps I take on a holiday will be less than on a non-holiday. I will test this hypothesis using a two sample, one tailed t-test. I will split my original data into two groups, one for holidays and one for non-holidays.
#
# ### Step 1:
# $H_0$: The average number of steps taken on a holiday $>$ the average number of steps taken on a non-holiday.
#
# $H_1$: The average number of steps taken on a holiday $\leq$ the average number of steps taken on a non-holiday
# ### Step 2:
# For this test I will be using a level of significance of $0.005$.
# ### Step 3:
# for our two-sample independent test of means we will have:
#
# test-statistic = $t = \frac{\bar X_1 - \bar X_2}{\sqrt{S_p ^2 (\frac{1}{n_1} + \frac{1}{n_2})}}$.
# ### Step 4:
# df = 4028
# t-critical $= 2.576$
#
# **Decision Rule:**
#
# If t-computed $> 2.576$, then reject $H_0$.
#
# If t-computed $\leq 2.576$, then DO NOT reject $H_0$.
#
# ### Step 5

# %%
t_computed, p_value = stats.ttest_ind(daily_steps[daily_steps.holiday == 1]['value'], daily_steps[daily_steps.holiday == 0]['value'])
print(abs(t_computed), p_value / 2)
# Out:
# 2.0162426866389405 0.02311698084896795

# %% [markdown]
# Since t-computed $(2.016) < 2.576$, then we do not reject $H_0$. So, we conclude that steps taken on a holiday $>$ than the steps taken on a non-holiday.

# %% [markdown]
# # Classification
# I am seeking to predict the number of steps taken on a day. For Classification, I used 3 models to see which would work best, I used a linear regressor, a kNN classifier, and a decision tree classifier to get predictions.

# %%
X = daily_steps.drop(columns = ['day of week', 'value'], axis=1)
Y = daily_steps['value'].astype(int)

# hold out
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# apply preprocessing to data
scaler = MinMaxScaler()
le = LabelEncoder()

# reshape for the min maxer
X['month'] = scaler.fit_transform(X['month'].values.reshape(-1,1))
#X['day of week'] = scaler.fit_transform(X['day of week'].values.reshape(-1,1))
X['date'] = le.fit_transform(X['date'])


# use random_state for reproducibility
# use stratify to ensure a similar distribution of
# class labels in your training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=0)

# %%
# Regression Model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import median_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import max_error
from sklearn.metrics import accuracy_score

reg = LinearRegression()
reg.fit(X_train, Y_train)

y_predicted = reg.predict(X_test)

mean_err = median_absolute_error(Y_test, y_predicted)
r2 = r2_score(Y_test, y_predicted)
max_err = max_error(Y_test, y_predicted)
print('Mean Squared Error:', mean_err)
print('R^2:', r2)
print('Max Error:', max_err)
# Out:
# Mean Squared Error: 1616.5211411020323
# R^2: -0.21699883195898573
# Max Error: 8681.705124619646

# %%
# kNN model
from sklearn.neighbors import KNeighborsClassifier

clf = KNeighborsClassifier(n_neighbors=5)
clf.fit(X_train, Y_train)

predicted = clf.predict(X_test)
accuracy = accuracy_score(Y_test, predicted)
print('kNN Classifier, k=5')
print('accuracy:', accuracy)
# Out:
# kNN Classifier, k=5
# accuracy: 0.0

# %%
# Decision Tree model
from sklearn.tree import DecisionTreeClassifier

dtree = DecisionTreeClassifier(random_state = 0)

dtree.fit(X_train, Y_train)

predicted = dtree.predict(X_test)
accuracy = accuracy_score(Y_test, predicted)

print('decision tree accuracy:', accuracy)
# Out:
# decision tree accuracy: 0.0
